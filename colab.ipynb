# %%
# !nvidia-smi
# Out:
# Fri Jan 14 22:32:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount("/content/gdrive")

ROOT = '/content/gdrive/MyDrive/DL/Transformer-fairseq/'
# %cd $ROOT
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/DL/Transformer-fairseq

# %%
# !bash 01.prepare-wmt20-news-commentary-v15-en-zh.sh

# %%
# !pip install -r requirements.txt
# !bash 02.install_fairseq.sh

import os
os.environ['PYTHONPATH'] += ':' + ROOT + 'fairseq/'
# Out:
# ...
# fatal: destination path 'fairseq' already exists and is not an empty directory.
# Obtaining file:///content/gdrive/My%20Drive/DL/Transformer-fairseq/fairseq
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 123 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 88 kB 7.3 MB/s
# ...
#      |████████████████████████████████| 90 kB 10.3 MB/s
# ...
#      |████████████████████████████████| 112 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 53.5 MB/s
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-py3-none-any.whl size=141230 sha256=6ed94a071b973419f1861fe3656b2a1769cacd1ae455a8fbad762559fa5d3aaa
#   Stored in directory: /root/.cache/pip/wheels/ca/33/b7/336836125fc9bb4ceaa4376d8abca10ca8bc84ddc824baea6c
# ...

# %%
# !bash 03.preprocess.sh
# Out:
# 2022-01-14 18:36:09 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# ...

# %%
# !pip install tensorboardX
# !bash 04.train.sh
# Out:
# ...
#      |████████████████████████████████| 124 kB 5.2 MB/s
# ...
